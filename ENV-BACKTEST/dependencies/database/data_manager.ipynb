# %%
# Out:
# Collecting pathlib
#   Downloading pathlib-1.0.1.tar.gz (49 kB)
# Note: you may need to restart the kernel to use updated packages.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\gam\anaconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\gam\\AppData\\Local\\Temp\\pip-install-aymzp1r5\\pathlib\\setup.py'"'"'; __file__='"'"'C:\\Users\\gam\\AppData\\Local\\Temp\\pip-install-aymzp1r5\\pathlib\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\gam\AppData\Local\Temp\pip-pip-egg-info-jg4bu9g8'
#          cwd: C:\Users\gam\AppData\Local\Temp\pip-install-aymzp1r5\pathlib\
#     Complete output (19 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\gam\AppData\Local\Temp\pip-install-aymzp1r5\pathlib\setup.py", line 6, in <module>
#         setup(
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_distutils\core.py", line 109, in setup
#         _setup_distribution = dist = klass(attrs)
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\dist.py", line 460, in __init__
#         for ep in metadata.entry_points(group='distutils.setup_keywords'):
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 999, in entry_points
#         return SelectableGroups.load(eps).select(**params)
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 449, in load
#         ordered = sorted(eps, key=by_group)
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 997, in <genexpr>
#         dist.entry_points for dist in unique(distributions())
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 609, in entry_points
#         return EntryPoints._from_text_for(self.read_text('entry_points.txt'), self)
#       File "C:\Users\gam\anaconda3\lib\site-packages\setuptools\_vendor\importlib_metadata\__init__.py", line 917, in read_text
#         return self._path.joinpath(filename).read_text(encoding='utf-8')
#     AttributeError: 'WindowsPath' object has no attribute 'read_text'
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
pip install ccxt
# Out:
# Requirement already satisfied: ccxt in c:\users\gam\anaconda3\lib\site-packages (1.77.62)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (3.1.1)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (61.2.0)
# Requirement already satisfied: requests>=2.18.4 in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (2.24.0)
# Requirement already satisfied: aiodns>=1.1.1; python_version >= "3.5.2" in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (3.0.0)
# Requirement already satisfied: aiohttp>=3.8; python_version >= "3.5.2" in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (3.8.1)
# Requirement already satisfied: yarl==1.7.2; python_version >= "3.5.2" in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (1.7.2)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\gam\anaconda3\lib\site-packages (from ccxt) (2020.6.20)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\users\gam\anaconda3\lib\site-packages (from cryptography>=2.6.1->ccxt) (1.14.3)
# Requirement already satisfied: six>=1.4.1 in c:\users\gam\anaconda3\lib\site-packages (from cryptography>=2.6.1->ccxt) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gam\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gam\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gam\anaconda3\lib\site-packages (from requests>=2.18.4->ccxt) (2.10)
# Requirement already satisfied: pycares>=4.0.0 in c:\users\gam\anaconda3\lib\site-packages (from aiodns>=1.1.1; python_version >= "3.5.2"->ccxt) (4.1.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (20.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (1.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (5.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in c:\users\gam\anaconda3\lib\site-packages (from aiohttp>=3.8; python_version >= "3.5.2"->ccxt) (2.0.12)
# Requirement already satisfied: pycparser in c:\users\gam\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.6.1->ccxt) (2.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append( 'C:/Users/gam/OneDrive - Groupe ESIEA/Bureau/Bots/backtest-ipynb/utilities')
from data_engine import DataEngine
import pandas as pd
import ccxt
import json
f = open('C:/Users/gam/OneDrive - Groupe ESIEA/Bureau/Bots/backtest-ipynb/database/pair_list.json')
pair_json = json.load(f)
f.close()

# %% [markdown]
# <h1>Inspect data from api or database</h1>

# %%
# -- Data variable --
pair_symbol = 'BTC/USDT'
timeframe = '15m'
start_date = '2017-01-01T00:00:00'

# -- Instance class --
dataEngine = DataEngine(session=ccxt.ftx())

# -- Check from exchange API --
df =dataEngine.get_historical_from_api(pair_symbol, timeframe, start_date)

# -- Check from local database --
# df =dataEngine.get_historical_from_db(pair_symbol, timeframe, start_date)

df
# Out:
#                          open      high       low     close       volume
# timestamp
# 2020-03-28 14:30:00   6243.25   6244.75   6223.50   6224.25       0.0000
# 2020-03-28 14:45:00   6224.25   6243.75   6223.25   6239.00       0.0000
# 2020-03-28 15:00:00   6239.00   6272.25   6237.25   6258.75       0.0000
# 2020-03-28 15:15:00   6258.75   6263.00   6227.00   6238.50     558.4800
# 2020-03-28 15:30:00   6238.50   6242.50   6212.00   6227.00       0.0000
# ...                       ...       ...       ...       ...          ...
# 2022-08-10 11:15:00  23085.00  23204.00  23084.00  23190.00  658686.5422
# 2022-08-10 11:30:00  23190.00  23192.00  23058.00  23107.00  745158.3272
# 2022-08-10 11:45:00  23107.00  23139.00  23073.00  23124.00  440082.3911
# 2022-08-10 12:00:00  23124.00  23184.00  23106.00  23183.00  488899.9771
# 2022-08-10 12:15:00  23183.00  23199.00  23156.00  23159.00   65826.7057
#
# [83030 rows x 5 columns]

# %% [markdown]
# <h1>Download data from api to local database</h1>

# %%
# -- Data variable --
pair_symbols = pair_json['all']
#pair_symbols = ['BTC/USDT']

# -- Instance class --
dataEngine = DataEngine(session=ccxt.ftx())

# -- Download data from data variable --
timeframes = ['1d']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['1w']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['1h']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['2h']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['3h']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['4h']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['5m']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['30m']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['45m']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['15m']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)

timeframes = ['5m']
start_date = '2017-01-01T00:00:00'
dataEngine.download_data(pair_symbols, timeframes, start_date)
# Out:
# -> downloding symbol BTC-PERP for timeframe 1d
# BTC-PERP 1036 Candles 1d load since the : 2019-07-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 1d
# ETH-PERP 1036 Candles 1d load since the : 2019-07-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 1d
# DOT-PERP 638 Candles 1d load since the : 2020-08-21 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/DOT-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 1d
# EGLD-PERP 499 Candles 1d load since the : 2021-01-07 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 1d
# AVAX-PERP 606 Candles 1d load since the : 2020-09-22 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 1d
# XRP-PERP 1036 Candles 1d load since the : 2019-07-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 1d
# MANA-PERP 250 Candles 1d load since the : 2021-09-13 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 1d
# XTZ-PERP 904 Candles 1d load since the : 2019-11-29 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 1d
# WAVES-PERP 556 Candles 1d load since the : 2020-11-11 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 1d
# ATOM-PERP 921 Candles 1d load since the : 2019-11-12 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 1d
# MATIC-PERP 942 Candles 1d load since the : 2019-10-22 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 1d
# KSM-PERP 492 Candles 1d load since the : 2021-01-14 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 1d
# LINK-PERP 949 Candles 1d load since the : 2019-10-15 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 1d
# SHIB-PERP 376 Candles 1d load since the : 2021-05-10 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 1d
# FTM-PERP 452 Candles 1d load since the : 2021-02-23 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 1d
# NEAR-PERP 438 Candles 1d load since the : 2021-03-09 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 1d
# SOL-PERP 663 Candles 1d load since the : 2020-07-27 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 1d
# THETA-PERP 725 Candles 1d load since the : 2020-05-26 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 1d
# CRO-PERP 423 Candles 1d load since the : 2021-03-24 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 1d
# FTT-PERP 503 Candles 1d load since the : 2021-01-03 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 1d
# RUNE-PERP 670 Candles 1d load since the : 2020-07-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 1d
# AAVE-PERP 586 Candles 1d load since the : 2020-10-12 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 1d
# AXS-PERP 410 Candles 1d load since the : 2021-04-06 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 1d
# GALA-PERP 183 Candles 1d load since the : 2021-11-19 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 1d
# SAND-PERP 424 Candles 1d load since the : 2021-03-23 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 1d
# NEO-PERP 601 Candles 1d load since the : 2020-09-27 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 1d
# LTC-PERP 1036 Candles 1d load since the : 2019-07-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 1d
# LRC-PERP 436 Candles 1d load since the : 2021-03-11 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 1d
# CAKE-PERP 437 Candles 1d load since the : 2021-03-10 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 1d
# XLM-PERP 541 Candles 1d load since the : 2020-11-26 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 1d
# COMP-PERP 701 Candles 1d load since the : 2020-06-19 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 1d
# SLP-PERP 313 Candles 1d load since the : 2021-07-12 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 1d
# APE-PERP 65 Candles 1d load since the : 2022-03-17 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 1d
# MTL-PERP 415 Candles 1d load since the : 2021-04-01 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 1d
# KAVA-PERP 439 Candles 1d load since the : 2021-03-08 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 1d
# CRV-PERP 498 Candles 1d load since the : 2021-01-08 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 1d
# SNX-PERP 547 Candles 1d load since the : 2020-11-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 1d
# LOOKS-PERP 130 Candles 1d load since the : 2022-01-11 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 1d
# XMR-PERP 504 Candles 1d load since the : 2021-01-02 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 1d
# TRX-PERP 1036 Candles 1d load since the : 2019-07-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 1d
# ZRX-PERP 449 Candles 1d load since the : 2021-02-26 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 1d
# PUNDIX-PERP 412 Candles 1d load since the : 2021-04-04 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 1d
# SUSHI-PERP 628 Candles 1d load since the : 2020-08-31 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 1d
# BCH-PERP 1036 Candles 1d load since the : 2019-07-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 1d
# BNB-PERP 1036 Candles 1d load since the : 2019-07-20 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 1d
# JASMY-PERP 50 Candles 1d load since the : 2022-04-01 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 1d
# ZIL-PERP 444 Candles 1d load since the : 2021-03-03 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 1d
# FIL-PERP 583 Candles 1d load since the : 2020-10-15 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 1d
# ADA-PERP 941 Candles 1d load since the : 2019-10-23 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 1d
# ETC-PERP 991 Candles 1d load since the : 2019-09-03 00:00:00 to : 2022-05-20 00:00:00 in ../database/FTX/1d/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 1w
# Error on BTC-PERP
# -> downloding symbol ETH-PERP for timeframe 1w
# Error on ETH-PERP
# -> downloding symbol DOT-PERP for timeframe 1w
# Error on DOT-PERP
# -> downloding symbol EGLD-PERP for timeframe 1w
# Error on EGLD-PERP
# -> downloding symbol AVAX-PERP for timeframe 1w
# Error on AVAX-PERP
# -> downloding symbol XRP-PERP for timeframe 1w
# Error on XRP-PERP
# -> downloding symbol MANA-PERP for timeframe 1w
# Error on MANA-PERP
# -> downloding symbol XTZ-PERP for timeframe 1w
# Error on XTZ-PERP
# -> downloding symbol WAVES-PERP for timeframe 1w
# Error on WAVES-PERP
# -> downloding symbol ATOM-PERP for timeframe 1w
# Error on ATOM-PERP
# -> downloding symbol MATIC-PERP for timeframe 1w
# Error on MATIC-PERP
# -> downloding symbol KSM-PERP for timeframe 1w
# Error on KSM-PERP
# -> downloding symbol LINK-PERP for timeframe 1w
# Error on LINK-PERP
# -> downloding symbol SHIB-PERP for timeframe 1w
# Error on SHIB-PERP
# -> downloding symbol FTM-PERP for timeframe 1w
# Error on FTM-PERP
# -> downloding symbol NEAR-PERP for timeframe 1w
# Error on NEAR-PERP
# -> downloding symbol SOL-PERP for timeframe 1w
# Error on SOL-PERP
# -> downloding symbol THETA-PERP for timeframe 1w
# Error on THETA-PERP
# -> downloding symbol CRO-PERP for timeframe 1w
# Error on CRO-PERP
# -> downloding symbol FTT-PERP for timeframe 1w
# Error on FTT-PERP
# -> downloding symbol RUNE-PERP for timeframe 1w
# Error on RUNE-PERP
# -> downloding symbol AAVE-PERP for timeframe 1w
# Error on AAVE-PERP
# -> downloding symbol AXS-PERP for timeframe 1w
# Error on AXS-PERP
# -> downloding symbol GALA-PERP for timeframe 1w
# Error on GALA-PERP
# -> downloding symbol SAND-PERP for timeframe 1w
# Error on SAND-PERP
# -> downloding symbol NEO-PERP for timeframe 1w
# Error on NEO-PERP
# -> downloding symbol LTC-PERP for timeframe 1w
# Error on LTC-PERP
# -> downloding symbol LRC-PERP for timeframe 1w
# Error on LRC-PERP
# -> downloding symbol CAKE-PERP for timeframe 1w
# Error on CAKE-PERP
# -> downloding symbol XLM-PERP for timeframe 1w
# Error on XLM-PERP
# -> downloding symbol COMP-PERP for timeframe 1w
# Error on COMP-PERP
# -> downloding symbol SLP-PERP for timeframe 1w
# Error on SLP-PERP
# -> downloding symbol APE-PERP for timeframe 1w
# Error on APE-PERP
# -> downloding symbol MTL-PERP for timeframe 1w
# Error on MTL-PERP
# -> downloding symbol KAVA-PERP for timeframe 1w
# Error on KAVA-PERP
# -> downloding symbol CRV-PERP for timeframe 1w
# Error on CRV-PERP
# -> downloding symbol SNX-PERP for timeframe 1w
# Error on SNX-PERP
# -> downloding symbol LOOKS-PERP for timeframe 1w
# Error on LOOKS-PERP
# -> downloding symbol XMR-PERP for timeframe 1w
# Error on XMR-PERP
# -> downloding symbol TRX-PERP for timeframe 1w
# Error on TRX-PERP
# -> downloding symbol ZRX-PERP for timeframe 1w
# Error on ZRX-PERP
# -> downloding symbol PUNDIX-PERP for timeframe 1w
# Error on PUNDIX-PERP
# -> downloding symbol SUSHI-PERP for timeframe 1w
# Error on SUSHI-PERP
# -> downloding symbol BCH-PERP for timeframe 1w
# Error on BCH-PERP
# -> downloding symbol BNB-PERP for timeframe 1w
# Error on BNB-PERP
# -> downloding symbol JASMY-PERP for timeframe 1w
# Error on JASMY-PERP
# -> downloding symbol ZIL-PERP for timeframe 1w
# Error on ZIL-PERP
# -> downloding symbol FIL-PERP for timeframe 1w
# Error on FIL-PERP
# -> downloding symbol ADA-PERP for timeframe 1w
# Error on ADA-PERP
# -> downloding symbol ETC-PERP for timeframe 1w
# Error on ETC-PERP
# -> downloding symbol BTC-PERP for timeframe 1h
# BTC-PERP 24843 Candles 1h load since the : 2019-07-20 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 1h
# ETH-PERP 24846 Candles 1h load since the : 2019-07-20 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 1h
# DOT-PERP 15286 Candles 1h load since the : 2020-08-21 20:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/DOT-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 1h
# EGLD-PERP 11965 Candles 1h load since the : 2021-01-07 05:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 1h
# AVAX-PERP 14532 Candles 1h load since the : 2020-09-22 06:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 1h
# XRP-PERP 24846 Candles 1h load since the : 2019-07-20 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 1h
# MANA-PERP 5984 Candles 1h load since the : 2021-09-13 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 1h
# XTZ-PERP 21679 Candles 1h load since the : 2019-11-29 11:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 1h
# WAVES-PERP 13329 Candles 1h load since the : 2020-11-11 09:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 1h
# ATOM-PERP 22098 Candles 1h load since the : 2019-11-12 00:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 1h
# MATIC-PERP 22578 Candles 1h load since the : 2019-10-22 23:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 1h
# KSM-PERP 11792 Candles 1h load since the : 2021-01-14 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 1h
# LINK-PERP 22760 Candles 1h load since the : 2019-10-15 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 1h
# SHIB-PERP 9005 Candles 1h load since the : 2021-05-10 13:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 1h
# FTM-PERP 10838 Candles 1h load since the : 2021-02-23 04:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 1h
# NEAR-PERP 10496 Candles 1h load since the : 2021-03-09 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 1h
# SOL-PERP 15906 Candles 1h load since the : 2020-07-27 00:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 1h
# THETA-PERP 17378 Candles 1h load since the : 2020-05-26 16:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 1h
# CRO-PERP 10136 Candles 1h load since the : 2021-03-24 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 1h
# FTT-PERP 12061 Candles 1h load since the : 2021-01-03 05:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 1h
# RUNE-PERP 16067 Candles 1h load since the : 2020-07-20 07:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 1h
# AAVE-PERP 14056 Candles 1h load since the : 2020-10-12 02:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 1h
# AXS-PERP 9824 Candles 1h load since the : 2021-04-06 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 1h
# GALA-PERP 4386 Candles 1h load since the : 2021-11-19 00:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 1h
# SAND-PERP 10158 Candles 1h load since the : 2021-03-23 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 1h
# NEO-PERP 14402 Candles 1h load since the : 2020-09-27 16:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 1h
# LTC-PERP 24846 Candles 1h load since the : 2019-07-20 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 1h
# LRC-PERP 10449 Candles 1h load since the : 2021-03-11 09:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 1h
# CAKE-PERP 10472 Candles 1h load since the : 2021-03-10 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 1h
# XLM-PERP 12978 Candles 1h load since the : 2020-11-26 00:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 1h
# COMP-PERP 16816 Candles 1h load since the : 2020-06-19 02:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 1h
# SLP-PERP 7494 Candles 1h load since the : 2021-07-12 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 1h
# APE-PERP 1542 Candles 1h load since the : 2022-03-17 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 1h
# MTL-PERP 9944 Candles 1h load since the : 2021-04-01 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 1h
# KAVA-PERP 10519 Candles 1h load since the : 2021-03-08 11:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 1h
# CRV-PERP 11940 Candles 1h load since the : 2021-01-08 06:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 1h
# SNX-PERP 13112 Candles 1h load since the : 2020-11-20 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 1h
# LOOKS-PERP 3098 Candles 1h load since the : 2022-01-11 16:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 1h
# XMR-PERP 12089 Candles 1h load since the : 2021-01-02 01:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 1h
# TRX-PERP 24846 Candles 1h load since the : 2019-07-20 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 1h
# ZRX-PERP 10760 Candles 1h load since the : 2021-02-26 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 1h
# PUNDIX-PERP 9868 Candles 1h load since the : 2021-04-04 14:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 1h
# SUSHI-PERP 15045 Candles 1h load since the : 2020-08-31 21:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 1h
# BCH-PERP 24845 Candles 1h load since the : 2019-07-20 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 1h
# BNB-PERP 24846 Candles 1h load since the : 2019-07-20 12:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 1h
# JASMY-PERP 1180 Candles 1h load since the : 2022-04-01 14:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 1h
# ZIL-PERP 10640 Candles 1h load since the : 2021-03-03 10:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 1h
# FIL-PERP 13972 Candles 1h load since the : 2020-10-15 14:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 1h
# ADA-PERP 22559 Candles 1h load since the : 2019-10-23 18:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 1h
# ETC-PERP 23772 Candles 1h load since the : 2019-09-03 05:00:00 to : 2022-05-20 17:00:00 in ../database/FTX/1h/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 2h
# Error empty dataframe on BTC-PERP
# -> downloding symbol ETH-PERP for timeframe 2h
# Error empty dataframe on ETH-PERP
# -> downloding symbol DOT-PERP for timeframe 2h
# Error empty dataframe on DOT-PERP
# -> downloding symbol EGLD-PERP for timeframe 2h
# Error empty dataframe on EGLD-PERP
# -> downloding symbol AVAX-PERP for timeframe 2h
# Error empty dataframe on AVAX-PERP
# -> downloding symbol XRP-PERP for timeframe 2h
# Error empty dataframe on XRP-PERP
# -> downloding symbol MANA-PERP for timeframe 2h
# Error empty dataframe on MANA-PERP
# -> downloding symbol XTZ-PERP for timeframe 2h
# Error empty dataframe on XTZ-PERP
# -> downloding symbol WAVES-PERP for timeframe 2h
# Error empty dataframe on WAVES-PERP
# -> downloding symbol ATOM-PERP for timeframe 2h
# Error empty dataframe on ATOM-PERP
# -> downloding symbol MATIC-PERP for timeframe 2h
# Error empty dataframe on MATIC-PERP
# -> downloding symbol KSM-PERP for timeframe 2h
# Error empty dataframe on KSM-PERP
# -> downloding symbol LINK-PERP for timeframe 2h
# Error empty dataframe on LINK-PERP
# -> downloding symbol SHIB-PERP for timeframe 2h
# Error empty dataframe on SHIB-PERP
# -> downloding symbol FTM-PERP for timeframe 2h
# Error empty dataframe on FTM-PERP
# -> downloding symbol NEAR-PERP for timeframe 2h
# Error empty dataframe on NEAR-PERP
# -> downloding symbol SOL-PERP for timeframe 2h
# Error empty dataframe on SOL-PERP
# -> downloding symbol THETA-PERP for timeframe 2h
# Error empty dataframe on THETA-PERP
# -> downloding symbol CRO-PERP for timeframe 2h
# Error empty dataframe on CRO-PERP
# -> downloding symbol FTT-PERP for timeframe 2h
# Error empty dataframe on FTT-PERP
# -> downloding symbol RUNE-PERP for timeframe 2h
# Error empty dataframe on RUNE-PERP
# -> downloding symbol AAVE-PERP for timeframe 2h
# Error empty dataframe on AAVE-PERP
# -> downloding symbol AXS-PERP for timeframe 2h
# Error empty dataframe on AXS-PERP
# -> downloding symbol GALA-PERP for timeframe 2h
# Error empty dataframe on GALA-PERP
# -> downloding symbol SAND-PERP for timeframe 2h
# Error empty dataframe on SAND-PERP
# -> downloding symbol NEO-PERP for timeframe 2h
# Error empty dataframe on NEO-PERP
# -> downloding symbol LTC-PERP for timeframe 2h
# Error empty dataframe on LTC-PERP
# -> downloding symbol LRC-PERP for timeframe 2h
# Error empty dataframe on LRC-PERP
# -> downloding symbol CAKE-PERP for timeframe 2h
# Error empty dataframe on CAKE-PERP
# -> downloding symbol XLM-PERP for timeframe 2h
# Error empty dataframe on XLM-PERP
# -> downloding symbol COMP-PERP for timeframe 2h
# Error empty dataframe on COMP-PERP
# -> downloding symbol SLP-PERP for timeframe 2h
# Error empty dataframe on SLP-PERP
# -> downloding symbol APE-PERP for timeframe 2h
# Error empty dataframe on APE-PERP
# -> downloding symbol MTL-PERP for timeframe 2h
# Error empty dataframe on MTL-PERP
# -> downloding symbol KAVA-PERP for timeframe 2h
# Error empty dataframe on KAVA-PERP
# -> downloding symbol CRV-PERP for timeframe 2h
# Error empty dataframe on CRV-PERP
# -> downloding symbol SNX-PERP for timeframe 2h
# Error empty dataframe on SNX-PERP
# -> downloding symbol LOOKS-PERP for timeframe 2h
# Error empty dataframe on LOOKS-PERP
# -> downloding symbol XMR-PERP for timeframe 2h
# Error empty dataframe on XMR-PERP
# -> downloding symbol TRX-PERP for timeframe 2h
# Error empty dataframe on TRX-PERP
# -> downloding symbol ZRX-PERP for timeframe 2h
# Error empty dataframe on ZRX-PERP
# -> downloding symbol PUNDIX-PERP for timeframe 2h
# Error empty dataframe on PUNDIX-PERP
# -> downloding symbol SUSHI-PERP for timeframe 2h
# Error empty dataframe on SUSHI-PERP
# -> downloding symbol BCH-PERP for timeframe 2h
# Error empty dataframe on BCH-PERP
# -> downloding symbol BNB-PERP for timeframe 2h
# Error empty dataframe on BNB-PERP
# -> downloding symbol JASMY-PERP for timeframe 2h
# Error empty dataframe on JASMY-PERP
# -> downloding symbol ZIL-PERP for timeframe 2h
# Error empty dataframe on ZIL-PERP
# -> downloding symbol FIL-PERP for timeframe 2h
# Error empty dataframe on FIL-PERP
# -> downloding symbol ADA-PERP for timeframe 2h
# Error empty dataframe on ADA-PERP
# -> downloding symbol ETC-PERP for timeframe 2h
# Error empty dataframe on ETC-PERP
# -> downloding symbol BTC-PERP for timeframe 3h
# Error empty dataframe on BTC-PERP
# -> downloding symbol ETH-PERP for timeframe 3h
# Error empty dataframe on ETH-PERP
# -> downloding symbol DOT-PERP for timeframe 3h
# Error empty dataframe on DOT-PERP
# -> downloding symbol EGLD-PERP for timeframe 3h
# Error empty dataframe on EGLD-PERP
# -> downloding symbol AVAX-PERP for timeframe 3h
# Error empty dataframe on AVAX-PERP
# -> downloding symbol XRP-PERP for timeframe 3h
# Error empty dataframe on XRP-PERP
# -> downloding symbol MANA-PERP for timeframe 3h
# Error empty dataframe on MANA-PERP
# -> downloding symbol XTZ-PERP for timeframe 3h
# Error empty dataframe on XTZ-PERP
# -> downloding symbol WAVES-PERP for timeframe 3h
# Error empty dataframe on WAVES-PERP
# -> downloding symbol ATOM-PERP for timeframe 3h
# Error empty dataframe on ATOM-PERP
# -> downloding symbol MATIC-PERP for timeframe 3h
# Error empty dataframe on MATIC-PERP
# -> downloding symbol KSM-PERP for timeframe 3h
# Error empty dataframe on KSM-PERP
# -> downloding symbol LINK-PERP for timeframe 3h
# Error empty dataframe on LINK-PERP
# -> downloding symbol SHIB-PERP for timeframe 3h
# Error empty dataframe on SHIB-PERP
# -> downloding symbol FTM-PERP for timeframe 3h
# Error empty dataframe on FTM-PERP
# -> downloding symbol NEAR-PERP for timeframe 3h
# Error empty dataframe on NEAR-PERP
# -> downloding symbol SOL-PERP for timeframe 3h
# Error empty dataframe on SOL-PERP
# -> downloding symbol THETA-PERP for timeframe 3h
# Error empty dataframe on THETA-PERP
# -> downloding symbol CRO-PERP for timeframe 3h
# Error empty dataframe on CRO-PERP
# -> downloding symbol FTT-PERP for timeframe 3h
# Error empty dataframe on FTT-PERP
# -> downloding symbol RUNE-PERP for timeframe 3h
# Error empty dataframe on RUNE-PERP
# -> downloding symbol AAVE-PERP for timeframe 3h
# Error empty dataframe on AAVE-PERP
# -> downloding symbol AXS-PERP for timeframe 3h
# Error empty dataframe on AXS-PERP
# -> downloding symbol GALA-PERP for timeframe 3h
# Error empty dataframe on GALA-PERP
# -> downloding symbol SAND-PERP for timeframe 3h
# Error empty dataframe on SAND-PERP
# -> downloding symbol NEO-PERP for timeframe 3h
# Error empty dataframe on NEO-PERP
# -> downloding symbol LTC-PERP for timeframe 3h
# Error empty dataframe on LTC-PERP
# -> downloding symbol LRC-PERP for timeframe 3h
# Error empty dataframe on LRC-PERP
# -> downloding symbol CAKE-PERP for timeframe 3h
# Error empty dataframe on CAKE-PERP
# -> downloding symbol XLM-PERP for timeframe 3h
# Error empty dataframe on XLM-PERP
# -> downloding symbol COMP-PERP for timeframe 3h
# Error empty dataframe on COMP-PERP
# -> downloding symbol SLP-PERP for timeframe 3h
# Error empty dataframe on SLP-PERP
# -> downloding symbol APE-PERP for timeframe 3h
# Error empty dataframe on APE-PERP
# -> downloding symbol MTL-PERP for timeframe 3h
# Error empty dataframe on MTL-PERP
# -> downloding symbol KAVA-PERP for timeframe 3h
# Error empty dataframe on KAVA-PERP
# -> downloding symbol CRV-PERP for timeframe 3h
# Error empty dataframe on CRV-PERP
# -> downloding symbol SNX-PERP for timeframe 3h
# Error empty dataframe on SNX-PERP
# -> downloding symbol LOOKS-PERP for timeframe 3h
# Error empty dataframe on LOOKS-PERP
# -> downloding symbol XMR-PERP for timeframe 3h
# Error empty dataframe on XMR-PERP
# -> downloding symbol TRX-PERP for timeframe 3h
# Error empty dataframe on TRX-PERP
# -> downloding symbol ZRX-PERP for timeframe 3h
# Error empty dataframe on ZRX-PERP
# -> downloding symbol PUNDIX-PERP for timeframe 3h
# Error empty dataframe on PUNDIX-PERP
# -> downloding symbol SUSHI-PERP for timeframe 3h
# Error empty dataframe on SUSHI-PERP
# -> downloding symbol BCH-PERP for timeframe 3h
# Error empty dataframe on BCH-PERP
# -> downloding symbol BNB-PERP for timeframe 3h
# Error empty dataframe on BNB-PERP
# -> downloding symbol JASMY-PERP for timeframe 3h
# Error empty dataframe on JASMY-PERP
# -> downloding symbol ZIL-PERP for timeframe 3h
# Error empty dataframe on ZIL-PERP
# -> downloding symbol FIL-PERP for timeframe 3h
# Error empty dataframe on FIL-PERP
# -> downloding symbol ADA-PERP for timeframe 3h
# Error empty dataframe on ADA-PERP
# -> downloding symbol ETC-PERP for timeframe 3h
# Error empty dataframe on ETC-PERP
# -> downloding symbol BTC-PERP for timeframe 4h
# BTC-PERP 6212 Candles 4h load since the : 2019-07-20 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 4h
# ETH-PERP 6212 Candles 4h load since the : 2019-07-20 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 4h
# DOT-PERP 3822 Candles 4h load since the : 2020-08-21 20:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/DOT-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 4h
# EGLD-PERP 2992 Candles 4h load since the : 2021-01-07 04:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 4h
# AVAX-PERP 3634 Candles 4h load since the : 2020-09-22 04:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 4h
# XRP-PERP 6212 Candles 4h load since the : 2019-07-20 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 4h
# MANA-PERP 1497 Candles 4h load since the : 2021-09-13 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 4h
# XTZ-PERP 5421 Candles 4h load since the : 2019-11-29 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 4h
# WAVES-PERP 3333 Candles 4h load since the : 2020-11-11 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 4h
# ATOM-PERP 5525 Candles 4h load since the : 2019-11-12 00:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 4h
# MATIC-PERP 5646 Candles 4h load since the : 2019-10-22 20:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 4h
# KSM-PERP 2949 Candles 4h load since the : 2021-01-14 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 4h
# LINK-PERP 5691 Candles 4h load since the : 2019-10-15 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 4h
# SHIB-PERP 2252 Candles 4h load since the : 2021-05-10 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 4h
# FTM-PERP 2710 Candles 4h load since the : 2021-02-23 04:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 4h
# NEAR-PERP 2625 Candles 4h load since the : 2021-03-09 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 4h
# SOL-PERP 3977 Candles 4h load since the : 2020-07-27 00:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 4h
# THETA-PERP 4345 Candles 4h load since the : 2020-05-26 16:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 4h
# CRO-PERP 2535 Candles 4h load since the : 2021-03-24 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 4h
# FTT-PERP 3016 Candles 4h load since the : 2021-01-03 04:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 4h
# RUNE-PERP 4018 Candles 4h load since the : 2020-07-20 04:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 4h
# AAVE-PERP 3515 Candles 4h load since the : 2020-10-12 00:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 4h
# AXS-PERP 2457 Candles 4h load since the : 2021-04-06 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 4h
# GALA-PERP 1097 Candles 4h load since the : 2021-11-19 00:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 4h
# SAND-PERP 2540 Candles 4h load since the : 2021-03-23 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 4h
# NEO-PERP 3601 Candles 4h load since the : 2020-09-27 16:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 4h
# LTC-PERP 6212 Candles 4h load since the : 2019-07-20 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 4h
# LRC-PERP 2613 Candles 4h load since the : 2021-03-11 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 4h
# CAKE-PERP 2619 Candles 4h load since the : 2021-03-10 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 4h
# XLM-PERP 3245 Candles 4h load since the : 2020-11-26 00:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 4h
# COMP-PERP 4205 Candles 4h load since the : 2020-06-19 00:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 4h
# SLP-PERP 1874 Candles 4h load since the : 2021-07-12 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 4h
# APE-PERP 386 Candles 4h load since the : 2022-03-17 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 4h
# MTL-PERP 2487 Candles 4h load since the : 2021-04-01 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 4h
# KAVA-PERP 2631 Candles 4h load since the : 2021-03-08 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 4h
# CRV-PERP 2986 Candles 4h load since the : 2021-01-08 04:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 4h
# SNX-PERP 3279 Candles 4h load since the : 2020-11-20 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 4h
# LOOKS-PERP 775 Candles 4h load since the : 2022-01-11 16:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 4h
# XMR-PERP 3023 Candles 4h load since the : 2021-01-02 00:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 4h
# TRX-PERP 6212 Candles 4h load since the : 2019-07-20 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 4h
# ZRX-PERP 2691 Candles 4h load since the : 2021-02-26 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 4h
# PUNDIX-PERP 2468 Candles 4h load since the : 2021-04-04 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 4h
# SUSHI-PERP 3762 Candles 4h load since the : 2020-08-31 20:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 4h
# BCH-PERP 6212 Candles 4h load since the : 2019-07-20 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 4h
# BNB-PERP 6212 Candles 4h load since the : 2019-07-20 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 4h
# JASMY-PERP 296 Candles 4h load since the : 2022-04-01 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 4h
# ZIL-PERP 2661 Candles 4h load since the : 2021-03-03 08:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 4h
# FIL-PERP 3494 Candles 4h load since the : 2020-10-15 12:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 4h
# ADA-PERP 5641 Candles 4h load since the : 2019-10-23 16:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 4h
# ETC-PERP 5944 Candles 4h load since the : 2019-09-03 04:00:00 to : 2022-05-20 16:00:00 in ../database/FTX/4h/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 5m
# BTC-PERP 291924 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 17:50:00 in ../database/FTX/5m/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 5m
# ETH-PERP 291925 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 17:55:00 in ../database/FTX/5m/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 5m
# DOT-PERP 179052 Candles 5m load since the : 2020-09-06 00:00:00 to : 2022-05-20 17:55:00 in ../database/FTX/5m/DOT-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 5m
# EGLD-PERP 138734 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 18:00:00 in ../database/FTX/5m/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 5m
# AVAX-PERP 170989 Candles 5m load since the : 2020-10-04 00:00:00 to : 2022-05-20 18:00:00 in ../database/FTX/5m/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 5m
# XRP-PERP 291927 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 18:05:00 in ../database/FTX/5m/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 5m
# MANA-PERP 66164 Candles 5m load since the : 2021-10-03 00:00:00 to : 2022-05-20 18:05:00 in ../database/FTX/5m/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 5m
# XTZ-PERP 259688 Candles 5m load since the : 2019-12-01 00:00:00 to : 2022-05-20 18:05:00 in ../database/FTX/5m/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 5m
# WAVES-PERP 154864 Candles 5m load since the : 2020-11-29 00:00:00 to : 2022-05-20 18:10:00 in ../database/FTX/5m/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 5m
# ATOM-PERP 259689 Candles 5m load since the : 2019-12-01 00:00:00 to : 2022-05-20 18:10:00 in ../database/FTX/5m/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 5m
# MATIC-PERP 267753 Candles 5m load since the : 2019-11-03 00:00:00 to : 2022-05-20 18:15:00 in ../database/FTX/5m/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 5m
# KSM-PERP 138737 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 18:15:00 in ../database/FTX/5m/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 5m
# LINK-PERP 267754 Candles 5m load since the : 2019-11-03 00:00:00 to : 2022-05-20 18:20:00 in ../database/FTX/5m/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 5m
# SHIB-PERP 106487 Candles 5m load since the : 2021-05-16 00:00:00 to : 2022-05-20 18:20:00 in ../database/FTX/5m/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 5m
# FTM-PERP 130046 Candles 5m load since the : 2021-02-23 04:45:00 to : 2022-05-20 18:20:00 in ../database/FTX/5m/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 5m
# NEAR-PERP 122616 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 18:25:00 in ../database/FTX/5m/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 5m
# SOL-PERP 187121 Candles 5m load since the : 2020-08-09 00:00:00 to : 2022-05-20 18:25:00 in ../database/FTX/5m/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 5m
# THETA-PERP 203247 Candles 5m load since the : 2020-06-14 00:00:00 to : 2022-05-20 18:30:00 in ../database/FTX/5m/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 5m
# CRO-PERP 121629 Candles 5m load since the : 2021-03-24 10:20:00 to : 2022-05-20 18:30:00 in ../database/FTX/5m/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 5m
# FTT-PERP 138740 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 18:30:00 in ../database/FTX/5m/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 5m
# RUNE-PERP 187123 Candles 5m load since the : 2020-08-09 00:00:00 to : 2022-05-20 18:35:00 in ../database/FTX/5m/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 5m
# AAVE-PERP 162933 Candles 5m load since the : 2020-11-01 00:00:00 to : 2022-05-20 18:35:00 in ../database/FTX/5m/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 5m
# AXS-PERP 114554 Candles 5m load since the : 2021-04-18 00:00:00 to : 2022-05-20 18:35:00 in ../database/FTX/5m/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 5m
# GALA-PERP 50042 Candles 5m load since the : 2021-11-28 00:00:00 to : 2022-05-20 18:35:00 in ../database/FTX/5m/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 5m
# SAND-PERP 121888 Candles 5m load since the : 2021-03-23 12:55:00 to : 2022-05-20 18:40:00 in ../database/FTX/5m/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 5m
# NEO-PERP 170997 Candles 5m load since the : 2020-10-04 00:00:00 to : 2022-05-20 18:40:00 in ../database/FTX/5m/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 5m
# LTC-PERP 291935 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 18:45:00 in ../database/FTX/5m/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 5m
# LRC-PERP 122620 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 18:45:00 in ../database/FTX/5m/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 5m
# CAKE-PERP 122620 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 18:45:00 in ../database/FTX/5m/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 5m
# XLM-PERP 154872 Candles 5m load since the : 2020-11-29 00:00:00 to : 2022-05-20 18:50:00 in ../database/FTX/5m/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 5m
# COMP-PERP 195187 Candles 5m load since the : 2020-07-12 00:00:00 to : 2022-05-20 18:50:00 in ../database/FTX/5m/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 5m
# SLP-PERP 89928 Candles 5m load since the : 2021-07-12 12:25:00 to : 2022-05-20 18:50:00 in ../database/FTX/5m/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 5m
# APE-PERP 17795 Candles 5m load since the : 2022-03-20 00:00:00 to : 2022-05-20 18:50:00 in ../database/FTX/5m/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 5m
# MTL-PERP 114558 Candles 5m load since the : 2021-04-18 00:00:00 to : 2022-05-20 18:55:00 in ../database/FTX/5m/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 5m
# KAVA-PERP 122622 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 18:55:00 in ../database/FTX/5m/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 5m
# CRV-PERP 138745 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 18:55:00 in ../database/FTX/5m/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 5m
# SNX-PERP 154874 Candles 5m load since the : 2020-11-29 00:00:00 to : 2022-05-20 19:00:00 in ../database/FTX/5m/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 5m
# LOOKS-PERP 33924 Candles 5m load since the : 2022-01-23 00:00:00 to : 2022-05-20 19:00:00 in ../database/FTX/5m/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 5m
# XMR-PERP 138746 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 19:00:00 in ../database/FTX/5m/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 5m
# TRX-PERP 291939 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 19:05:00 in ../database/FTX/5m/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 5m
# ZRX-PERP 122624 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 19:05:00 in ../database/FTX/5m/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 5m
# PUNDIX-PERP 114560 Candles 5m load since the : 2021-04-18 00:00:00 to : 2022-05-20 19:05:00 in ../database/FTX/5m/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 5m
# SUSHI-PERP 179067 Candles 5m load since the : 2020-09-06 00:00:00 to : 2022-05-20 19:10:00 in ../database/FTX/5m/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 5m
# BCH-PERP 291934 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 19:10:00 in ../database/FTX/5m/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 5m
# BNB-PERP 291941 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 19:15:00 in ../database/FTX/5m/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 5m
# JASMY-PERP 9736 Candles 5m load since the : 2022-04-17 00:00:00 to : 2022-05-20 19:15:00 in ../database/FTX/5m/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 5m
# ZIL-PERP 122626 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 19:15:00 in ../database/FTX/5m/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 5m
# FIL-PERP 162942 Candles 5m load since the : 2020-11-01 00:00:00 to : 2022-05-20 19:20:00 in ../database/FTX/5m/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 5m
# ADA-PERP 267766 Candles 5m load since the : 2019-11-03 00:00:00 to : 2022-05-20 19:20:00 in ../database/FTX/5m/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 5m
# ETC-PERP 283874 Candles 5m load since the : 2019-09-08 00:00:00 to : 2022-05-20 19:25:00 in ../database/FTX/5m/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 30m
# Error empty dataframe on BTC-PERP
# -> downloding symbol ETH-PERP for timeframe 30m
# Error empty dataframe on ETH-PERP
# -> downloding symbol DOT-PERP for timeframe 30m
# Error empty dataframe on DOT-PERP
# -> downloding symbol EGLD-PERP for timeframe 30m
# Error empty dataframe on EGLD-PERP
# -> downloding symbol AVAX-PERP for timeframe 30m
# Error empty dataframe on AVAX-PERP
# -> downloding symbol XRP-PERP for timeframe 30m
# Error empty dataframe on XRP-PERP
# -> downloding symbol MANA-PERP for timeframe 30m
# Error empty dataframe on MANA-PERP
# -> downloding symbol XTZ-PERP for timeframe 30m
# Error empty dataframe on XTZ-PERP
# -> downloding symbol WAVES-PERP for timeframe 30m
# Error empty dataframe on WAVES-PERP
# -> downloding symbol ATOM-PERP for timeframe 30m
# Error empty dataframe on ATOM-PERP
# -> downloding symbol MATIC-PERP for timeframe 30m
# Error empty dataframe on MATIC-PERP
# -> downloding symbol KSM-PERP for timeframe 30m
# Error empty dataframe on KSM-PERP
# -> downloding symbol LINK-PERP for timeframe 30m
# Error empty dataframe on LINK-PERP
# -> downloding symbol SHIB-PERP for timeframe 30m
# Error empty dataframe on SHIB-PERP
# -> downloding symbol FTM-PERP for timeframe 30m
# Error empty dataframe on FTM-PERP
# -> downloding symbol NEAR-PERP for timeframe 30m
# Error empty dataframe on NEAR-PERP
# -> downloding symbol SOL-PERP for timeframe 30m
# Error empty dataframe on SOL-PERP
# -> downloding symbol THETA-PERP for timeframe 30m
# Error empty dataframe on THETA-PERP
# -> downloding symbol CRO-PERP for timeframe 30m
# Error empty dataframe on CRO-PERP
# -> downloding symbol FTT-PERP for timeframe 30m
# Error empty dataframe on FTT-PERP
# -> downloding symbol RUNE-PERP for timeframe 30m
# Error empty dataframe on RUNE-PERP
# -> downloding symbol AAVE-PERP for timeframe 30m
# Error empty dataframe on AAVE-PERP
# -> downloding symbol AXS-PERP for timeframe 30m
# Error empty dataframe on AXS-PERP
# -> downloding symbol GALA-PERP for timeframe 30m
# Error empty dataframe on GALA-PERP
# -> downloding symbol SAND-PERP for timeframe 30m
# Error empty dataframe on SAND-PERP
# -> downloding symbol NEO-PERP for timeframe 30m
# Error empty dataframe on NEO-PERP
# -> downloding symbol LTC-PERP for timeframe 30m
# Error empty dataframe on LTC-PERP
# -> downloding symbol LRC-PERP for timeframe 30m
# Error empty dataframe on LRC-PERP
# -> downloding symbol CAKE-PERP for timeframe 30m
# Error empty dataframe on CAKE-PERP
# -> downloding symbol XLM-PERP for timeframe 30m
# Error empty dataframe on XLM-PERP
# -> downloding symbol COMP-PERP for timeframe 30m
# Error empty dataframe on COMP-PERP
# -> downloding symbol SLP-PERP for timeframe 30m
# ...
# -> downloding symbol XTZ-PERP for timeframe 15m
# XTZ-PERP 86574 Candles 15m load since the : 2019-12-01 00:00:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 15m
# WAVES-PERP 53320 Candles 15m load since the : 2020-11-11 09:30:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 15m
# ATOM-PERP 88396 Candles 15m load since the : 2019-11-12 00:30:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 15m
# MATIC-PERP 89262 Candles 15m load since the : 2019-11-03 00:00:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 15m
# KSM-PERP 46254 Candles 15m load since the : 2021-01-24 00:00:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 15m
# LINK-PERP 91042 Candles 15m load since the : 2019-10-15 10:00:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 15m
# SHIB-PERP 35503 Candles 15m load since the : 2021-05-16 00:00:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 15m
# FTM-PERP 43356 Candles 15m load since the : 2021-02-23 04:45:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 15m
# NEAR-PERP 40879 Candles 15m load since the : 2021-03-21 00:00:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 15m
# SOL-PERP 62382 Candles 15m load since the : 2020-08-09 00:00:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 15m
# THETA-PERP 69517 Candles 15m load since the : 2020-05-26 16:15:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 15m
# CRO-PERP 40550 Candles 15m load since the : 2021-03-24 10:15:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 15m
# FTT-PERP 48247 Candles 15m load since the : 2021-01-03 05:45:00 to : 2022-05-20 19:30:00 in ../database/FTX/15m/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 15m
# RUNE-PERP 64273 Candles 15m load since the : 2020-07-20 07:30:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 15m
# AAVE-PERP 56229 Candles 15m load since the : 2020-10-12 02:30:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 15m
# AXS-PERP 38192 Candles 15m load since the : 2021-04-18 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 15m
# GALA-PERP 16688 Candles 15m load since the : 2021-11-28 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 15m
# SAND-PERP 40637 Candles 15m load since the : 2021-03-23 12:45:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 15m
# NEO-PERP 57007 Candles 15m load since the : 2020-10-04 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 15m
# LTC-PERP 99380 Candles 15m load since the : 2019-07-20 12:30:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 15m
# LRC-PERP 40880 Candles 15m load since the : 2021-03-21 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 15m
# CAKE-PERP 40880 Candles 15m load since the : 2021-03-21 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 15m
# XLM-PERP 51631 Candles 15m load since the : 2020-11-29 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 15m
# COMP-PERP 67269 Candles 15m load since the : 2020-06-19 02:30:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 15m
# SLP-PERP 29983 Candles 15m load since the : 2021-07-12 12:15:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 15m
# APE-PERP 5936 Candles 15m load since the : 2022-03-20 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 15m
# MTL-PERP 38192 Candles 15m load since the : 2021-04-18 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 15m
# KAVA-PERP 40880 Candles 15m load since the : 2021-03-21 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 15m
# CRV-PERP 46255 Candles 15m load since the : 2021-01-24 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 15m
# SNX-PERP 51631 Candles 15m load since the : 2020-11-29 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 15m
# LOOKS-PERP 11312 Candles 15m load since the : 2022-01-23 00:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 15m
# XMR-PERP 48361 Candles 15m load since the : 2021-01-02 01:30:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 15m
# TRX-PERP 99380 Candles 15m load since the : 2019-07-20 12:30:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 15m
# ZRX-PERP 43048 Candles 15m load since the : 2021-02-26 10:00:00 to : 2022-05-20 19:45:00 in ../database/FTX/15m/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 15m
# PUNDIX-PERP 38193 Candles 15m load since the : 2021-04-18 00:00:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 15m
# SUSHI-PERP 59696 Candles 15m load since the : 2020-09-06 00:00:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 15m
# BCH-PERP 99379 Candles 15m load since the : 2019-07-20 12:30:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 15m
# BNB-PERP 99381 Candles 15m load since the : 2019-07-20 12:30:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 15m
# JASMY-PERP 3249 Candles 15m load since the : 2022-04-17 00:00:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 15m
# ZIL-PERP 40881 Candles 15m load since the : 2021-03-21 00:00:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 15m
# FIL-PERP 54320 Candles 15m load since the : 2020-11-01 00:00:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 15m
# ADA-PERP 89264 Candles 15m load since the : 2019-11-03 00:00:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 15m
# ETC-PERP 94634 Candles 15m load since the : 2019-09-08 00:00:00 to : 2022-05-20 20:00:00 in ../database/FTX/15m/ETC-PERP.p
# -> downloding symbol BTC-PERP for timeframe 5m
# BTC-PERP 291951 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 20:05:00 in ../database/FTX/5m/BTC-PERP.p
# -> downloding symbol ETH-PERP for timeframe 5m
# ETH-PERP 291952 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 20:10:00 in ../database/FTX/5m/ETH-PERP.p
# -> downloding symbol DOT-PERP for timeframe 5m
# DOT-PERP 179079 Candles 5m load since the : 2020-09-06 00:00:00 to : 2022-05-20 20:10:00 in ../database/FTX/5m/DOT-PERP.p
# -> downloding symbol EGLD-PERP for timeframe 5m
# EGLD-PERP 138761 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 20:15:00 in ../database/FTX/5m/EGLD-PERP.p
# -> downloding symbol AVAX-PERP for timeframe 5m
# AVAX-PERP 171016 Candles 5m load since the : 2020-10-04 00:00:00 to : 2022-05-20 20:15:00 in ../database/FTX/5m/AVAX-PERP.p
# -> downloding symbol XRP-PERP for timeframe 5m
# XRP-PERP 291954 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 20:20:00 in ../database/FTX/5m/XRP-PERP.p
# -> downloding symbol MANA-PERP for timeframe 5m
# MANA-PERP 66191 Candles 5m load since the : 2021-10-03 00:00:00 to : 2022-05-20 20:20:00 in ../database/FTX/5m/MANA-PERP.p
# -> downloding symbol XTZ-PERP for timeframe 5m
# XTZ-PERP 259715 Candles 5m load since the : 2019-12-01 00:00:00 to : 2022-05-20 20:20:00 in ../database/FTX/5m/XTZ-PERP.p
# -> downloding symbol WAVES-PERP for timeframe 5m
# WAVES-PERP 154891 Candles 5m load since the : 2020-11-29 00:00:00 to : 2022-05-20 20:25:00 in ../database/FTX/5m/WAVES-PERP.p
# -> downloding symbol ATOM-PERP for timeframe 5m
# ATOM-PERP 259716 Candles 5m load since the : 2019-12-01 00:00:00 to : 2022-05-20 20:25:00 in ../database/FTX/5m/ATOM-PERP.p
# -> downloding symbol MATIC-PERP for timeframe 5m
# MATIC-PERP 267780 Candles 5m load since the : 2019-11-03 00:00:00 to : 2022-05-20 20:30:00 in ../database/FTX/5m/MATIC-PERP.p
# -> downloding symbol KSM-PERP for timeframe 5m
# KSM-PERP 138764 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 20:30:00 in ../database/FTX/5m/KSM-PERP.p
# -> downloding symbol LINK-PERP for timeframe 5m
# LINK-PERP 267781 Candles 5m load since the : 2019-11-03 00:00:00 to : 2022-05-20 20:35:00 in ../database/FTX/5m/LINK-PERP.p
# -> downloding symbol SHIB-PERP for timeframe 5m
# SHIB-PERP 106514 Candles 5m load since the : 2021-05-16 00:00:00 to : 2022-05-20 20:35:00 in ../database/FTX/5m/SHIB-PERP.p
# -> downloding symbol FTM-PERP for timeframe 5m
# FTM-PERP 130073 Candles 5m load since the : 2021-02-23 04:45:00 to : 2022-05-20 20:35:00 in ../database/FTX/5m/FTM-PERP.p
# -> downloding symbol NEAR-PERP for timeframe 5m
# NEAR-PERP 122642 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 20:35:00 in ../database/FTX/5m/NEAR-PERP.p
# -> downloding symbol SOL-PERP for timeframe 5m
# SOL-PERP 187148 Candles 5m load since the : 2020-08-09 00:00:00 to : 2022-05-20 20:40:00 in ../database/FTX/5m/SOL-PERP.p
# -> downloding symbol THETA-PERP for timeframe 5m
# THETA-PERP 203273 Candles 5m load since the : 2020-06-14 00:00:00 to : 2022-05-20 20:40:00 in ../database/FTX/5m/THETA-PERP.p
# -> downloding symbol CRO-PERP for timeframe 5m
# CRO-PERP 121656 Candles 5m load since the : 2021-03-24 10:20:00 to : 2022-05-20 20:45:00 in ../database/FTX/5m/CRO-PERP.p
# -> downloding symbol FTT-PERP for timeframe 5m
# FTT-PERP 138767 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 20:45:00 in ../database/FTX/5m/FTT-PERP.p
# -> downloding symbol RUNE-PERP for timeframe 5m
# RUNE-PERP 187149 Candles 5m load since the : 2020-08-09 00:00:00 to : 2022-05-20 20:45:00 in ../database/FTX/5m/RUNE-PERP.p
# -> downloding symbol AAVE-PERP for timeframe 5m
# AAVE-PERP 162960 Candles 5m load since the : 2020-11-01 00:00:00 to : 2022-05-20 20:50:00 in ../database/FTX/5m/AAVE-PERP.p
# -> downloding symbol AXS-PERP for timeframe 5m
# AXS-PERP 114581 Candles 5m load since the : 2021-04-18 00:00:00 to : 2022-05-20 20:50:00 in ../database/FTX/5m/AXS-PERP.p
# -> downloding symbol GALA-PERP for timeframe 5m
# GALA-PERP 50069 Candles 5m load since the : 2021-11-28 00:00:00 to : 2022-05-20 20:50:00 in ../database/FTX/5m/GALA-PERP.p
# -> downloding symbol SAND-PERP for timeframe 5m
# SAND-PERP 121914 Candles 5m load since the : 2021-03-23 12:55:00 to : 2022-05-20 20:50:00 in ../database/FTX/5m/SAND-PERP.p
# -> downloding symbol NEO-PERP for timeframe 5m
# NEO-PERP 171024 Candles 5m load since the : 2020-10-04 00:00:00 to : 2022-05-20 20:55:00 in ../database/FTX/5m/NEO-PERP.p
# -> downloding symbol LTC-PERP for timeframe 5m
# LTC-PERP 291961 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 20:55:00 in ../database/FTX/5m/LTC-PERP.p
# -> downloding symbol LRC-PERP for timeframe 5m
# LRC-PERP 122647 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 21:00:00 in ../database/FTX/5m/LRC-PERP.p
# -> downloding symbol CAKE-PERP for timeframe 5m
# CAKE-PERP 122647 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 21:00:00 in ../database/FTX/5m/CAKE-PERP.p
# -> downloding symbol XLM-PERP for timeframe 5m
# XLM-PERP 154898 Candles 5m load since the : 2020-11-29 00:00:00 to : 2022-05-20 21:00:00 in ../database/FTX/5m/XLM-PERP.p
# -> downloding symbol COMP-PERP for timeframe 5m
# COMP-PERP 195214 Candles 5m load since the : 2020-07-12 00:00:00 to : 2022-05-20 21:05:00 in ../database/FTX/5m/COMP-PERP.p
# -> downloding symbol SLP-PERP for timeframe 5m
# SLP-PERP 89955 Candles 5m load since the : 2021-07-12 12:25:00 to : 2022-05-20 21:05:00 in ../database/FTX/5m/SLP-PERP.p
# -> downloding symbol APE-PERP for timeframe 5m
# APE-PERP 17822 Candles 5m load since the : 2022-03-20 00:00:00 to : 2022-05-20 21:05:00 in ../database/FTX/5m/APE-PERP.p
# -> downloding symbol MTL-PERP for timeframe 5m
# MTL-PERP 114584 Candles 5m load since the : 2021-04-18 00:00:00 to : 2022-05-20 21:05:00 in ../database/FTX/5m/MTL-PERP.p
# -> downloding symbol KAVA-PERP for timeframe 5m
# KAVA-PERP 122649 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 21:10:00 in ../database/FTX/5m/KAVA-PERP.p
# -> downloding symbol CRV-PERP for timeframe 5m
# CRV-PERP 138772 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 21:10:00 in ../database/FTX/5m/CRV-PERP.p
# -> downloding symbol SNX-PERP for timeframe 5m
# SNX-PERP 154900 Candles 5m load since the : 2020-11-29 00:00:00 to : 2022-05-20 21:10:00 in ../database/FTX/5m/SNX-PERP.p
# -> downloding symbol LOOKS-PERP for timeframe 5m
# LOOKS-PERP 33950 Candles 5m load since the : 2022-01-23 00:00:00 to : 2022-05-20 21:10:00 in ../database/FTX/5m/LOOKS-PERP.p
# -> downloding symbol XMR-PERP for timeframe 5m
# XMR-PERP 138773 Candles 5m load since the : 2021-01-24 00:00:00 to : 2022-05-20 21:15:00 in ../database/FTX/5m/XMR-PERP.p
# -> downloding symbol TRX-PERP for timeframe 5m
# TRX-PERP 291965 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 21:15:00 in ../database/FTX/5m/TRX-PERP.p
# -> downloding symbol ZRX-PERP for timeframe 5m
# ZRX-PERP 122651 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 21:20:00 in ../database/FTX/5m/ZRX-PERP.p
# -> downloding symbol PUNDIX-PERP for timeframe 5m
# PUNDIX-PERP 114587 Candles 5m load since the : 2021-04-18 00:00:00 to : 2022-05-20 21:20:00 in ../database/FTX/5m/PUNDIX-PERP.p
# -> downloding symbol SUSHI-PERP for timeframe 5m
# SUSHI-PERP 179093 Candles 5m load since the : 2020-09-06 00:00:00 to : 2022-05-20 21:20:00 in ../database/FTX/5m/SUSHI-PERP.p
# -> downloding symbol BCH-PERP for timeframe 5m
# BCH-PERP 291961 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 21:25:00 in ../database/FTX/5m/BCH-PERP.p
# -> downloding symbol BNB-PERP for timeframe 5m
# BNB-PERP 291967 Candles 5m load since the : 2019-08-11 00:00:00 to : 2022-05-20 21:25:00 in ../database/FTX/5m/BNB-PERP.p
# -> downloding symbol JASMY-PERP for timeframe 5m
# JASMY-PERP 9762 Candles 5m load since the : 2022-04-17 00:00:00 to : 2022-05-20 21:25:00 in ../database/FTX/5m/JASMY-PERP.p
# -> downloding symbol ZIL-PERP for timeframe 5m
# ZIL-PERP 122653 Candles 5m load since the : 2021-03-21 00:00:00 to : 2022-05-20 21:30:00 in ../database/FTX/5m/ZIL-PERP.p
# -> downloding symbol FIL-PERP for timeframe 5m
# FIL-PERP 162968 Candles 5m load since the : 2020-11-01 00:00:00 to : 2022-05-20 21:30:00 in ../database/FTX/5m/FIL-PERP.p
# -> downloding symbol ADA-PERP for timeframe 5m
# ADA-PERP 267793 Candles 5m load since the : 2019-11-03 00:00:00 to : 2022-05-20 21:35:00 in ../database/FTX/5m/ADA-PERP.p
# -> downloding symbol ETC-PERP for timeframe 5m
# ETC-PERP 283900 Candles 5m load since the : 2019-09-08 00:00:00 to : 2022-05-20 21:35:00 in ../database/FTX/5m/ETC-PERP.p

# %% [markdown]
# <h1>Update data from local database with new data from api</h1>

# %%
# -- Data variable --
pair_symbols = pair_json['TopperfFTX']
#pair_symbols = ['BNB/USDT']
timeframes = ['1h']

# -- Instance class --
dataEngine = DataEngine(session=ccxt.binance())

# -- Download data from data variable --
dataEngine.update_data(pair_symbols, timeframes)
# Out:
# Error on BTC-PERP 1h
# Error on ETH-PERP 1h
# Error on DOT-PERP 1h
# Error on LUNA-PERP 1h
# Error on EGLD-PERP 1h
# Error on AVAX-PERP 1h
# Error on XRP-PERP 1h
# Error on MANA-PERP 1h
# Error on XTZ-PERP 1h
# Error on WAVES-PERP 1h
# Error on ATOM-PERP 1h
# Error on MATIC-PERP 1h
# Error on KSM-PERP 1h
# Error on LINK-PERP 1h
# Error on SHIB-PERP 1h
# Error on FTM-PERP 1h
# Error on NEAR-PERP 1h
# Error on SOL-PERP 1h
# Error on HBAR-PERP 1h
# Error on THETA-PERP 1h
# Error on CRO-PERP 1h
# Error on LEO-PERP 1h
# Error on HT-PERP 1h
# Error on FTT-PERP 1h
# Error on ROSE-PERP 1h
# Error on RUNE-PERP 1h
# Error on AAVE-PERP 1h
# Error on AXS-PERP 1h
# Error on GALA-PERP 1h
# Error on SAND-PERP 1h
# Error on DASH-PERP 1h
# Error on NEO-PERP 1h
# Error on LTC-PERP 1h
# Error on EOS-PERP 1h
# Error on LRC-PERP 1h
# Error on CAKE-PERP 1h
# Error on ADA-PERP 1h
# Error on BNB-PERP 1h
# Error on XLM-PERP 1h
# Error on XEM-PERP 1h
# Error on COMP-PERP 1h
# Error on AUDIO-PERP 1h
# Error on SLP-PERP 1h
# Error on APE-PERP 1h
